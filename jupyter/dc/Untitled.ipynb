# %%
import pandas as pd

# %%
import csv

# %%
with open("/home/adam/Downloads/Test.csv", 'r') as rfile:
    reader = csv.DictReader(rfile)
    for line in reader:
        print(line)
# Out:
# OrderedDict([(None, ['<!DOCTYPE html>'])])
# OrderedDict([(None, ['<html lang="en">'])])
# OrderedDict([(None, ['  <head>'])])
# OrderedDict([(None, ['    <meta charset="utf-8">'])])
# OrderedDict([(None, ['  <link rel="dns-prefetch" href="https://github.githubassets.com">'])])
# OrderedDict([(None, ['  <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">'])])
# OrderedDict([(None, ['  <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">'])])
# OrderedDict([(None, ['  <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">'])])
# OrderedDict([(None, ['  <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">'])])
# OrderedDict([(None, ['  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">'])])
# OrderedDict([(None, ['  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">'])])
# ...

# %%
reader.fieldnames
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-9076051a98d2> in <module>
# ----> 1 reader.fieldnames
#
# ~/anaconda3/envs/wheelway/lib/python3.7/csv.py in fieldnames(self)
#      96         if self._fieldnames is None:
#      97             try:
# ---> 98                 self._fieldnames = next(self.reader)
#      99             except StopIteration:
#     100                 pass
#
# ValueError: I/O operation on closed file.
